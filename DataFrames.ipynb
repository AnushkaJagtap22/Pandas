# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name ' : [ 'John' , 'Anna' , 'Peter' , 'Tom'],
    'Age '  : [ 20 , 30 , 19 , 21 ],
    'City'  : ['Paris' , 'London' , 'Mumbai' , 'Sydney'],
    'Salary': [20000 , 10000 , 23000 , 13000]
}
df = pd.DataFrame(data)
df
# Out:
#    Name   Age     City  Salary
# 0   John    20   Paris   20000
# 1   Anna    30  London   10000
# 2  Peter    19  Mumbai   23000
# 3    Tom    21  Sydney   13000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
columns = ["Name" , "Age" , "City" , "Salary"] 
df2 = pd.DataFrame(data_list,columns = columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2[ "Designation" ] = ["HR" , "CEO" , "Manager" , "HR"]
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000          HR
# 1   Anna   34     Paris   70000         CEO
# 2  Peter   29    Berlin   62000     Manager
# 3  Linda   42    London   85000          HR

# %%
df2[ "Designation" ] = ["HR" , "CEO" , "Manager" , "HR"]
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000          HR
# 1   Anna   34     Paris   70000         CEO
# 2  Peter   29    Berlin   62000     Manager
# 3  Linda   42    London   85000          HR

# %%
df2.drop("Designation" , axis = 1, inplace = True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Age grater than 20
df2[df2["Age"]> 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#Age greater than 30 and city = PARIS
df2[(df2["Age"] > 30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
